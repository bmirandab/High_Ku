# %%
from pymongo import MongoClient
from pprint import pprint
import pickle

# %%
client = MongoClient()

# %%
db = client.haikudb

# %%
collection = db['haikus']

# %%
with open('haiku_dict.pickle', 'rb') as handle:
    haiku_dict = pickle.load(handle)

# %%
# collection.insert(haiku_dict)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# [ObjectId('5c6effa1381f610c8533f034'),
#  ObjectId('5c6effa1381f610c8533f035'),
#  ObjectId('5c6effa1381f610c8533f036'),
#  ObjectId('5c6effa1381f610c8533f037'),
#  ObjectId('5c6effa1381f610c8533f038'),
#  ObjectId('5c6effa1381f610c8533f039'),
#  ObjectId('5c6effa1381f610c8533f03a'),
#  ObjectId('5c6effa1381f610c8533f03b'),
#  ObjectId('5c6effa1381f610c8533f03c'),
#  ObjectId('5c6effa1381f610c8533f03d'),
#  ObjectId('5c6effa1381f610c8533f03e'),
#  ObjectId('5c6effa1381f610c8533f03f'),
#  ObjectId('5c6effa1381f610c8533f040'),
#  ObjectId('5c6effa1381f610c8533f041'),
#  ObjectId('5c6effa1381f610c8533f042'),
#  ObjectId('5c6effa1381f610c8533f043'),
#  ObjectId('5c6effa1381f610c8533f044'),
#  ObjectId('5c6effa1381f610c8533f045'),
#  ObjectId('5c6effa1381f610c8533f046'),
# ...

# %%
db.haikus.estimated_document_count()
# Out:
# 14996
